# %%
import pandas as pd

# %%
time_data = pd.read_csv("sickle_cell_clinical_note.csv")

time_data.head()
# Out:
#   patient_id visit_datetime facility_type   pain_type  pain_intensity  \
# 0     P00000        10/8/20            ER    Leg Pain               2
# 1     P00000       12/26/20        Clinic  Chest Pain               8
# 2     P00000        2/21/21    Outpatient  Chest Pain               4
# 3     P00000         8/7/21        Clinic    Leg Pain               8
# 4     P00000        10/4/21   Urgent Care   Back Pain               6
#
#         location admitted  hemoglobin  oxygen_saturation weather  \
# 0          Bronx      Yes         6.6                 98     Hot
# 1         Queens      Yes         6.7                 92   Humid
# 2  Staten Island       No        10.5                 88   Rainy
# 3      Manhattan       No         9.2                 95   Rainy
# 4          Bronx       No         7.8                 91    Cold
#
#                                        clinical_note       dob diagnosis_date  \
# ...

# %%
time_data.location.value_counts().plot(kind='bar', title='Location of Patient')
# Out:
# <Axes: title={'center': 'Location of Patient'}, xlabel='location'>

# %%
time_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75016 entries, 0 to 75015
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   patient_id         75016 non-null  str
#  1   visit_datetime     75016 non-null  str
#  2   facility_type      75016 non-null  str
#  3   pain_type          75016 non-null  str
#  4   pain_intensity     75016 non-null  int64
#  5   location           75016 non-null  str
#  6   admitted           75016 non-null  str
#  7   hemoglobin         75016 non-null  float64
#  8   oxygen_saturation  75016 non-null  int64
#  9   weather            75016 non-null  str
#  10  clinical_note      75016 non-null  str
#  11  dob                75016 non-null  str
#  12  diagnosis_date     75016 non-null  str
#  13  gender             75016 non-null  str
#  14  race               75016 non-null  str
# dtypes: float64(1), int64(2), str(12)
# memory usage: 8.6 MB

# %%
time_data.location.value_counts()
# Out:
# location
# Staten Island    15150
# Bronx            15085
# Manhattan        15036
# Queens           15004
# Brooklyn         14741
# Name: count, dtype: int64
